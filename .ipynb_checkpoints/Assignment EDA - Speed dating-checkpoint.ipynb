# %% [markdown]
# <div>
# <img src=https://www.institutedata.com/wp-content/uploads/2019/10/iod_h_tp_primary_c.svg width="300">
# </div>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns
# get matplot to show charts inline
# %matplotlib inline

# %%
# Question: What attributes increases the chance of someone finding a match
df = pd.read_csv('../data/Speed Dating Data.csv', encoding = "ISO-8859-1")

# %%
# Remove empty columns
df = df.dropna(how='all', axis=1)

#drop unnessary columns
df = df.drop(df.filter(regex='has_null').columns, axis=1)
df = df.drop(df.filter(regex='2_1').columns, axis=1)
df = df.drop(df.filter(regex='3_1').columns, axis=1)
df = df.drop(df.filter(regex='5_1').columns, axis=1)

df.head()
# Out:
#    iid   id  gender  idg  condtn  wave  round  position  positin1  order  \
# 0    1  1.0       0    1       1     1     10         7       NaN      4
# 1    1  1.0       0    1       1     1     10         7       NaN      3
# 2    1  1.0       0    1       1     1     10         7       NaN     10
# 3    1  1.0       0    1       1     1     10         7       NaN      5
# 4    1  1.0       0    1       1     1     10         7       NaN      7
#
#    partner   pid  match  int_corr  samerace  age_o  race_o  pf_o_att  \
# 0        1  11.0      0      0.14         0   27.0     2.0      35.0
# 1        2  12.0      0      0.54         0   22.0     2.0      60.0
# 2        3  13.0      1      0.16         1   22.0     4.0      19.0
# 3        4  14.0      1      0.61         0   23.0     2.0      30.0
# 4        5  15.0      1      0.21         0   24.0     3.0      30.0
#
#    pf_o_sin  pf_o_int  pf_o_fun  pf_o_amb  pf_o_sha  dec_o  attr_o  sinc_o  \
# ...

# %%
#more filtering

newData = df.filter(['id', 'gender', 'match', 'age_o', 'race_o', 'field','undergrd','imprace', 'imprelig', 'from','zipcode','income', 'goal', 'career', 'exhappy', 'attr1_1', 'sinc1_1', 'intel1_1', 'fun1_1', 'amb1_1', 'shar1_1'])
# Out:
#         id  gender  match  age_o  race_o             field  imprace  imprelig  \
# 0      1.0       0      0   27.0     2.0               Law      2.0       4.0
# 1      1.0       0      0   22.0     2.0               Law      2.0       4.0
# 2      1.0       0      1   22.0     4.0               Law      2.0       4.0
# 3      1.0       0      1   23.0     2.0               Law      2.0       4.0
# 4      1.0       0      1   24.0     3.0               Law      2.0       4.0
# ...    ...     ...    ...    ...     ...               ...      ...       ...
# 8373  22.0       1      0   26.0     3.0  Climate Dynamics      1.0       1.0
# 8374  22.0       1      0   24.0     6.0  Climate Dynamics      1.0       1.0
# 8375  22.0       1      0   29.0     3.0  Climate Dynamics      1.0       1.0
# 8376  22.0       1      0   22.0     4.0  Climate Dynamics      1.0       1.0
# 8377   NaN       1      0   22.0     4.0  Climate Dynamics      1.0       1.0
#
# ...

# %% [markdown]
# 100 points to distribute among the following attributes
#
# attr1_1
# Attractive
#
# sinc1_1
# Sincere
#
# intel1_1
# Intelligent
#
# fun1_1
# Fun
#
# amb1_1
# Ambitious
#
# shar1_1
# Has shared interests/hobbies

# %%
#data based on what user is looking for in their partner
lookforData = df.filter(['match','attr1_1', 'sinc1_1', 'intel1_1', 'fun1_1', 'amb1_1', 'shar1_1'])

#rename columns

# %%
matchedData = lookforData.loc[lookforData.match == 1]
unmatchedData = lookforData.loc[lookforData.match == 0]
#plot correlation graph

#find the number of matches
print('Found Someone: ' + str(matchedData.match.size))
print('Found Noone: ' + str(unmatchedData.match.size))

#sns.load_dataset(matchedData)
#sns.pairplot(matchedData)
# Out:
# Found Someone: 1380
# Found Noone: 6998

# %%
#described people who found a match during the event
matchedData.describe()
# Out:
#         match     attr1_1      sinc1_1     intel1_1       fun1_1       amb1_1  \
# count  1380.0  1365.00000  1365.000000  1365.000000  1363.000000  1360.000000
# mean      1.0    22.93874    16.883026    20.480967    18.028371    10.621154
# std       0.0    13.83699     7.078063     6.735570     6.400820     6.170268
# min       1.0     0.00000     0.000000     0.000000     0.000000     0.000000
# 25%       1.0    15.00000    14.000000    18.000000    15.000000     5.000000
# 50%       1.0    20.00000    18.000000    20.000000    19.230000    10.000000
# 75%       1.0    25.00000    20.000000    25.000000    20.000000    15.000000
# max       1.0   100.00000    60.000000    50.000000    50.000000    53.000000
#
#            shar1_1
# count  1360.000000
# mean     11.152882
# std       6.434088
# min       0.000000
# 25%       5.000000
# 50%      10.000000
# 75%      15.000000
# max      30.000000

# %%
#described people who found no match during the event
unmatchedData.describe()
# Out:
#         match      attr1_1      sinc1_1     intel1_1       fun1_1  \
# count  6998.0  6934.000000  6934.000000  6934.000000  6926.000000
# mean      0.0    22.431144    17.497447    20.223219    17.344609
# std       0.0    12.326194     7.036611     6.791980     6.015281
# min       0.0     0.000000     0.000000     0.000000     0.000000
# 25%       0.0    15.000000    15.000000    17.310000    15.000000
# 50%       0.0    20.000000    18.750000    20.000000    18.000000
# 75%       0.0    25.000000    20.000000    23.260000    20.000000
# max       0.0   100.000000    60.000000    50.000000    50.000000
#
#             amb1_1      shar1_1
# count  6919.000000  6897.000000
# mean     10.694605    11.981609
# std       6.116305     6.339427
# min       0.000000     0.000000
# 25%       5.000000    10.000000
# 50%      10.000000    11.540000
# 75%      15.000000    16.000000
# max      53.000000    30.000000

# %%
sns.heatmap(newData.corr())

# %%
df.head(10)

df.importance_same_religion.value_counts().sort_values()
# Out:
# 9.0      282
# 10.0     327
# 7.0      467
# 8.0      517
# 4.0      524
# 6.0      661
# 5.0      697
# 2.0      863
# 3.0      929
# 1.0     3032
# Name: importance_same_religion, dtype: int64

# %%
print(df.columns)
# Out:
# Index(['has_null', 'wave', 'gender', 'age', 'age_o', 'd_age', 'd_d_age',
#        'race', 'race_o', 'samerace',
#        ...
#        'd_expected_num_interested_in_me', 'd_expected_num_matches', 'like',
#        'guess_prob_liked', 'd_like', 'd_guess_prob_liked', 'met', 'decision',
#        'decision_o', 'match'],
#       dtype='object', length=123)

# %%
df.attractive.value_counts()
# Out:
# 7.0     2914
# 8.0     2217
# 6.0     1100
# 9.0      729
# 5.0      642
# 10.0     268
# 4.0      238
# 3.0      145
# 2.0       20
# Name: attractive, dtype: int64

# %%
df.race.value_counts()
# Out:
# european/caucasian-american              4727
# asian/pacific islander/asian-american    1982
# latino/hispanic american                  664
# other                                     522
# black/african american                    420
# Name: race, dtype: int64

# %%
df.age.value_counts()
# Out:
# 27.0    1059
# 23.0     894
# 26.0     869
# 24.0     863
# 25.0     837
# 28.0     746
# 22.0     655
# 29.0     589
# 30.0     574
# 21.0     291
# 32.0     210
# 33.0     161
# 34.0     152
# 31.0     125
# 35.0      60
# 20.0      55
# 36.0      45
# 19.0      20
# 42.0      20
# 38.0      19
# 39.0      18
# 18.0      10
# 55.0       6
# 37.0       5
# Name: age, dtype: int64

# %%
# Which race

# %%
df.pref_o_attractive.apply(np.round).value_counts()
# Out:
# 20.0     1726
# 15.0     1148
# 10.0      853
# 25.0      818
# 30.0      679
# 40.0      356
# 16.0      300
# 50.0      300
# 17.0      289
# 35.0      212
# 18.0      204
# 14.0      196
# 19.0      161
# 21.0      131
# 12.0       96
# 5.0        60
# 22.0       58
# 60.0       57
# 24.0       55
# 13.0       55
# 8.0        55
# 9.0        44
# 23.0       43
# 70.0       40
# 7.0        40
# 75.0       38
# 11.0       32
# 28.0       30
# 45.0       28
# 58.0       22
# 27.0       21
# 0.0        21
# 32.0       20
# 26.0       20
# 95.0       18
# 55.0       16
# 33.0       10
# 100.0      10
# 80.0        9
# 2.0         9
# 90.0        9
# Name: pref_o_attractive, dtype: int64

# %%
df.field.value_counts()
# Out:
# business                 631
# law                      604
# mba                      468
# social work              414
# international affairs    287
#                         ...
# stats                      6
# mfa  poetry                6
# math of finance            6
# theory                     5
# marine geophysics          5
# Name: field, Length: 219, dtype: int64

# %%
# Out:
#       has_null  wave  gender   age  age_o  d_age d_d_age  \
# 0            0     1  female  21.0   27.0      6   [4-6]
# 1            0     1  female  21.0   22.0      1   [0-1]
# 2            1     1  female  21.0   22.0      1   [0-1]
# 3            0     1  female  21.0   23.0      2   [2-3]
# 4            0     1  female  21.0   24.0      3   [2-3]
# ...        ...   ...     ...   ...    ...    ...     ...
# 8373         1    21    male  25.0   26.0      1   [0-1]
# 8374         1    21    male  25.0   24.0      1   [0-1]
# 8375         1    21    male  25.0   29.0      4   [4-6]
# 8376         1    21    male  25.0   22.0      3   [2-3]
# 8377         1    21    male  25.0   22.0      3   [2-3]
#
#                                        race  \
# 0     asian/pacific islander/asian-american
# 1     asian/pacific islander/asian-american
# 2     asian/pacific islander/asian-american
# 3     asian/pacific islander/asian-american
# 4     asian/pacific islander/asian-american
# ...

# %%
#Median #correlation map
